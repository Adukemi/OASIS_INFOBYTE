# %% [markdown]
# <a href="https://colab.research.google.com/github/Adukemi/OIBISP_TASKNO/blob/main/Project3_L2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project 3, Level 2**
#
# # Fraud Detection

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
import numpy as np
import joblib

# %%
df = pd.read_csv("/content/creditcard.csv")
#df.info()
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
df.isnull().sum()

#df.fillna(0, inplace=True)  # Filling with 0
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.654067e-16 -3.568593e-16  2.578648e-16  4.473266e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   5.340915e-16  1.683437e-15 -3.660091e-16 -1.227390e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
# Feature Scaling: Since features like Amount vary widely, apply scaling
scaler = StandardScaler()
df['Amount'] = scaler.fit_transform(df[['Amount']])

# Handle Class Imbalance : Fraud datasets are often imbalanced. Using techniques like SMOTE.
X = df.drop('Class', axis=1)
y = df['Class']

X = X[~y.isnull()]  # Keep rows where 'y' is not NaN
y = y[~y.isnull()]  # Keep corresponding 'y' values

smote = SMOTE()
X_resampled, y_resampled = smote.fit_resample(X, y)

# Print the value counts
value_counts = pd.Series(y_resampled).value_counts()
print(value_counts)
print("\n")

# Draw a barchart
plt.figure(figsize=(8, 6))
sns.barplot(x=value_counts.index, y=value_counts.values, palette=['blue', 'green'], hue=value_counts.index, legend=False)
plt.title('Class Distribution After Resampling')
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.show()
# Out:
# Class
# 0    284315
# 1    284315
# Name: count, dtype: int64

# %%
# Feature Engineering
# Feature Correlation: heatmap to identify important features:

correlation = df.corr()
plt.figure(figsize=(16, 12))
sns.heatmap(correlation, annot=False, cmap='coolwarm')
plt.show()

# %%
# Dimensionality Reduction: If features V15-V28 are PCA components, retain the most important ones.
pca = PCA(n_components=10)
X_pca = pca.fit_transform(X_resampled)

# Split the Dataset: Divide the data into training and testing sets:
X_train, X_test, y_train, y_test = train_test_split(X_pca, y_resampled, test_size=0.3, random_state=42)

# Train Models
models = {
    "Logistic Regression": LogisticRegression(max_iter=2000),  # Increased max_iter
    "Decision Tree": DecisionTreeClassifier(),
    "Neural Network": MLPClassifier(max_iter=2000)  # Added Neural Network
}

# Evaluate the model
results = {}

for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    y_pred_proba = model.predict_proba(X_test)[:, 1]
    roc_auc = roc_auc_score(y_test, y_pred_proba)
    results[name] = {
        "Confusion Matrix": confusion_matrix(y_test, y_pred),
        "Classification Report": classification_report(y_test, y_pred),
        "ROC-AUC Score": roc_auc,
        "ROC Curve": roc_curve(y_test, y_pred_proba)
    }

# Plot the results and determine the best model
best_model = max(results, key=lambda k: results[k]["ROC-AUC Score"])

for name, result in results.items():
    print(f"\nModel: {name}")
    print("\nConfusion Matrix:\n", result["Confusion Matrix"])
    print("\nClassification Report:\n", result["Classification Report"])
    print("ROC-AUC Score:", result["ROC-AUC Score"])
    print("\n" + "="*60 + "\n")

    # Plot Confusion Matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(result["Confusion Matrix"], annot=True, fmt='d', cmap='Blues')
    plt.title(f'Confusion Matrix for {name}')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()
    print("\n")

    # Plot ROC Curve
    fpr, tpr, _ = result["ROC Curve"]
    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, label=f'{name} (AUC = {result["ROC-AUC Score"]:.2f})')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve for {name}')
    plt.legend(loc='lower right')
    plt.show()
    print("\n")

print(f"Best Model: {best_model} with ROC-AUC Score: {results[best_model]['ROC-AUC Score']}")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:697: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# Model: Logistic Regression
#
# Confusion Matrix:
#  [[84347   802]
#  [ 2837 82603]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     85149
#            1       0.99      0.97      0.98     85440
#
#     accuracy                           0.98    170589
#    macro avg       0.98      0.98      0.98    170589
# weighted avg       0.98      0.98      0.98    170589
#
# ROC-AUC Score: 0.996960230841548
#
# ============================================================
# Model: Decision Tree
#
# Confusion Matrix:
#  [[84937   212]
#  [  114 85326]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85149
#            1       1.00      1.00      1.00     85440
#
#     accuracy                           1.00    170589
#    macro avg       1.00      1.00      1.00    170589
# weighted avg       1.00      1.00      1.00    170589
#
# ROC-AUC Score: 0.9980879885405108
#
# ============================================================
# Model: Neural Network
#
# Confusion Matrix:
#  [[83301  1848]
#  [ 2855 82585]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97     85149
#            1       0.98      0.97      0.97     85440
#
#     accuracy                           0.97    170589
#    macro avg       0.97      0.97      0.97    170589
# weighted avg       0.97      0.97      0.97    170589
#
# ROC-AUC Score: 0.9931393516462197
#
# ============================================================
# Best Model: Decision Tree with ROC-AUC Score: 0.9980879885405108

# %%
# Check the percentage of fraud
fraud_percentage = df['Class'].value_counts(normalize=True) * 100
print("Fraud Percentage:\n ",fraud_percentage)

print('\nLegitimate(0):', round(df['Class'].value_counts()[0]/len(df) * 100,2), '% of the dataset')
print('Frauds(1):', round(df['Class'].value_counts()[1]/len(df) * 100,2), '% of the dataset')
print("\n")

# Checking for class imbalance
sns.countplot(x='Class', data=df)
plt.title('Class Distribution (Fraud vs Non-Fraud)')
plt.show()
# Out:
# Fraud Percentage:
#   Class
# 0    99.827251
# 1     0.172749
# Name: proportion, dtype: float64
#
# Legitimate(0): 99.83 % of the dataset
# Frauds(1): 0.17 % of the dataset

# %%
fig, ax = plt.subplots(1, 2, figsize=(18,4))

amount_val = df['Amount'].values
time_val = df['Time'].values

sns.histplot(amount_val, ax=ax[0], color='red', kde=True)
ax[0].set_title('Transaction Amount Distribution', fontsize=14)
ax[0].set_xlim([min(amount_val), max(amount_val)])

sns.histplot(time_val, ax=ax[1], color='purple', kde=True)
ax[1].set_title('Transaction Time Distribution', fontsize=14)
ax[1].set_xlim([min(time_val), max(time_val)])

plt.show()

# %%
# Splitting the data into features and target
X = df.drop('Class', axis=1)
y = df['Class']

# Standardizing the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Training a logistic regression model
model = LogisticRegression()
model.fit(X_scaled, y)

# Save the model and scaler for real-time use
joblib.dump(model, 'fraud_detection_model.pkl')
joblib.dump(scaler, 'scaler.pkl')

# Function to detect fraud in real-time
def detect_fraud(transaction):
    """
    Detects if a transaction is fraudulent.

    Parameters:
    transaction (dict): A dictionary containing transaction details with keys as column names.

    Returns:
    bool: True if the transaction is fraudulent, False otherwise.
    """
    # Load the model and scaler
    model = joblib.load('fraud_detection_model.pkl')
    scaler = joblib.load('scaler.pkl')

    # Convert the transaction to a dataframe
    transaction_df = pd.DataFrame([transaction])

    # Standardize the transaction data
    transaction_scaled = scaler.transform(transaction_df)

    # Predict if the transaction is fraudulent
    prediction = model.predict(transaction_scaled)

    return bool(prediction[0])

# Example usage
new_transaction = {
    "Time": 100000.0,
    "V1": -1.3598071336738,
    "V2": -0.0727811733098497,
    "V3": 2.53634673796914,
    "V4": 1.37815522427443,
    "V5": -0.338320769942518,
    "V6": 0.462387777762292,
    "V7": 0.239598554061257,
    "V8": 0.0986979012610507,
    "V9": 0.363786969611213,
    "V10": 0.0907941719789316,
    "V11": -0.551599533260813,
    "V12": -0.617800855762348,
    "V13": -0.991389847235408,
    "V14": -0.311169353699879,
    "V15": 1.46817697209427,
    "V16": -0.470400525259478,
    "V17": 0.207971241929242,
    "V18": 0.0257905801985591,
    "V19": 0.403992960255733,
    "V20": 0.251412098239705,
    "V21": -0.018306777944153,
    "V22": 0.277837575558899,
    "V23": -0.110473910188767,
    "V24": 0.0669280749146731,
    "V25": 0.128539358273528,
    "V26": -0.189114843888824,
    "V27": 0.133558376740387,
    "V28": -0.0210530534538215,
    "Amount": 149.62
}

is_fraud = detect_fraud(new_transaction)
is_fraud
# Out:
# True

# %% [markdown]
# # **Insights and Recommendations**
#
# **Insights:**
# - The dataset is highly imbalanced, with only 0.17% fraudulent transactions.
# - Resampling methods effectively balanced the data for training.
# - Neural Networks showed the best balance between precision and recall, while Decision Trees may have overfitted.
# - Correlation among features suggests opportunities for dimensionality reduction.
# - Fraud patterns may correlate with transaction amounts or times.
#
# **Recommendations:**
# - Use Neural Networks or ensemble models for deployment due to better generalization.
# - Prioritize recall to minimize missed fraud cases.
# - Evaluate on imbalanced test sets to ensure real-world effectiveness.
# - Regularly retrain the model and monitor evolving fraud patterns.
